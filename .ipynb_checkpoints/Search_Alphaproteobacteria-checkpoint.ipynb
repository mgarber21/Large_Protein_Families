# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys
import seaborn as sns
import random

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## PATHS

# %%
SampledTCSpath = os.path.join(os.getcwd(), "SampledTCS") #TCS identified from sampled geneomes
SampledGenomespath = os.path.join(os.getcwd(), "SampledGenomes") #list of sampled genomes from a taxanomic level
Genomespath = os.path.join(os.getcwd(), "GenomeDBs") #list of genomes for a taxanomic level
Source_path = os.path.join(os.getcwd(), "Source_Files") #.hmm files

TSNEpath = os.path.join(os.getcwd(), "TSNE_output") #store output from TSNE

# %%
TSNEs = []
for i in range(1,4):
    proteobactTSNE = pd.read_csv(os.path.join(TSNEpath, f"TSNEProteobacteriaDB_{i}.csv"))
    TSNEs.append(proteobactTSNE)

# %%
def palette(source):
    order = ['no domain', 'Trans_reg_C', 'HTH_8', 'GerE', 'Sigma54_activat']
    colors = [ "#000000", "#e3ac2d","#de1c07","#0209d6","#de1c07"]
    
    orderedDomainPalette = dict(zip(order, colors))

    AllDomains =  source["DBD"].unique()
    n=len(AllDomains)*10
    greys= sns.color_palette("Greys",n_colors = n, desat=0)[int(n*.3):int(n*0.7)]
    AllDomainsPalette = dict()
    for i, domain in enumerate(AllDomains):
        if domain in order:
            AllDomainsPalette[domain] = orderedDomainPalette[domain]
        else:
            AllDomainsPalette[domain] = greys[i]
            
    
    
    
    return AllDomainsPalette

# %%
def pos_neg():
    return 1 if random.random() < 0.5 else -1
pos_neg()
# Out:
# 1

# %%
fig1, axes  = plt.subplots(figsize =  (30,10), ncols=3)


for ax, source in zip(axes, TSNEs):





    sns.scatterplot(data =source, x ="tsne-pca500-one", y= "tsne-pca500-two",
                    hue = "DBD",
                    size = 10,
                    # hue_order= ordering + [i for i in source["DBD"].unique() if i not in ordering],
                    legend = False,
                    palette= palette(source),
                    alpha = 0.4,
                    ax=ax
                   )

    # ax.set_title(level)

fig2, axes  = plt.subplots(figsize =  (30,10), ncols=3)


for ax, source in zip(axes, TSNEs):


    subsource = source[(source["species"] == "PP") |
                       (source["class"]=="Alphaproteobacteria")
                      ]
    sns.scatterplot(data =subsource, x ="tsne-pca500-one", y= "tsne-pca500-two",
                    hue = "DBD",
                    s = 150,
                    style = "class",
                    marker = "P",
                    # hue_order= hue_order,
                    legend = False,
                    palette= palette(source),
                    ax=ax,
                    alpha = 0.9
                   )
    TEXTS = []
    for x,y,text in zip(subsource["tsne-pca500-one"], subsource["tsne-pca500-two"], subsource["id"]):
        # Only append selected countries
        text = text.split('-')[1]
        if text in ["PP_5241","PP_3551", "PP_1066", "PP_1401", "PP_0263"]:
            TEXTS.append(ax.annotate(text, xy=(x, y), xycoords='data',
                                     fontsize=12,
                                     xytext=(x+random.randrange(25)/100*pos_neg(), 
                                             y+random.randrange(25)/100*pos_neg()), 
                                     textcoords='offset points',
                                     arrowprops=dict(arrowstyle="-", color='grey', alpha=0.5)))



    # ax.set_title(level)
# Out:
# /usr/local/share/jupyteruser/.virtualenvs/biopython_3.8-kHq-BLTU/lib/python3.8/site-packages/seaborn/relational.py:657: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# /usr/local/share/jupyteruser/.virtualenvs/biopython_3.8-kHq-BLTU/lib/python3.8/site-packages/seaborn/relational.py:657: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# /usr/local/share/jupyteruser/.virtualenvs/biopython_3.8-kHq-BLTU/lib/python3.8/site-packages/seaborn/relational.py:657: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# /usr/local/share/jupyteruser/.virtualenvs/biopython_3.8-kHq-BLTU/lib/python3.8/site-packages/seaborn/relational.py:657: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# /usr/local/share/jupyteruser/.virtualenvs/biopython_3.8-kHq-BLTU/lib/python3.8/site-packages/seaborn/relational.py:657: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# /usr/local/share/jupyteruser/.virtualenvs/biopython_3.8-kHq-BLTU/lib/python3.8/site-packages/seaborn/relational.py:657: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)

# %%
TSNE = TSNEs[1]
TSNE[TSNE["id"].str.contains("PP_3551")]
# Out:
#      Unnamed: 0  gene_id          version          phylum  \
# 199         199  PP_3551  GCF_000007565.2  Proteobacteria
#
#                    class            order            family        genus  \
# 199  Gammaproteobacteria  Pseudomonadales  Pseudomonadaceae  Pseudomonas
#
#               species_x   DBD                       id species  \
# 199  Pseudomonas putida  GerE  GCF_000007565.2-PP_3551      PP
#
#      tsne-pca500-one  tsne-pca500-two
# 199        11.464013         7.843095

# %%
TSNE[TSNE["id"].str.contains("PP_1066")]
# Out:
#      Unnamed: 0  gene_id          version          phylum  \
# 233         233  PP_1066  GCF_000007565.2  Proteobacteria
#
#                    class            order            family        genus  \
# 233  Gammaproteobacteria  Pseudomonadales  Pseudomonadaceae  Pseudomonas
#
#               species_x    DBD                       id species  \
# 233  Pseudomonas putida  HTH_8  GCF_000007565.2-PP_1066      PP
#
#      tsne-pca500-one  tsne-pca500-two
# 233          8.30312         9.515757

# %%
TSNE[
    (TSNE["tsne-pca500-one"]>7) &
    (TSNE["tsne-pca500-one"]<14) &
    (TSNE["tsne-pca500-two"]>2) &
    (TSNE["tsne-pca500-two"]<11) & 
    (TSNE["class"].str.contains("Alp"))
     
          ]
# Out:
#       Unnamed: 0        gene_id          version          phylum  \
# 1005        1005   BJ6T_RS38780  GCF_000284375.1  Proteobacteria
# 1015        1015   BJ6T_RS33775  GCF_000284375.1  Proteobacteria
# 1016        1016   BJ6T_RS33770  GCF_000284375.1  Proteobacteria
# 1027        1027   BJ6T_RS30105  GCF_000284375.1  Proteobacteria
# 1039        1039   BJ6T_RS23775  GCF_000284375.1  Proteobacteria
# 1051        1051   BJ6T_RS11840  GCF_000284375.1  Proteobacteria
# 1052        1052   BJ6T_RS11835  GCF_000284375.1  Proteobacteria
# 1054        1054   BJ6T_RS11250  GCF_000284375.1  Proteobacteria
# 1055        1055   BJ6T_RS16295  GCF_000284375.1  Proteobacteria
# 1056        1056   BJ6T_RS15935  GCF_000284375.1  Proteobacteria
# 1060        1060   BJ6T_RS15240  GCF_000284375.1  Proteobacteria
# 1061        1061   BJ6T_RS15235  GCF_000284375.1  Proteobacteria
# 1087        1087   BJ6T_RS01625  GCF_000284375.1  Proteobacteria
# 1090        1090   BJ6T_RS01290  GCF_000284375.1  Proteobacteria
# 1111        1111  BLT50_RS02205  GCF_900100005.1  Proteobacteria
# 1135        1135  B0E33_RS18315  GCF_001999245.1  Proteobacteria
# 1154        1154  B0E33_RS09385  GCF_001999245.1  Proteobacteria
# 1156        1156  B0E33_RS11640  GCF_001999245.1  Proteobacteria
# 1161        1161  B0E33_RS06900  GCF_001999245.1  Proteobacteria
# 1166        1166  B0E33_RS05065  GCF_001999245.1  Proteobacteria
# 1170        1170  B0E33_RS04150  GCF_001999245.1  Proteobacteria
# 1182        1182   PFRI_RS12995  GCF_001890925.1  Proteobacteria
# 1189        1189   PFRI_RS09560  GCF_001890925.1  Proteobacteria
#
#                     class            order             family           genus  \
# 1005  Alphaproteobacteria      Rhizobiales  Bradyrhizobiaceae  Bradyrhizobium
# 